# %% [markdown]
# ### Connecting to a Database

# %%
# Installing mysqlconnector

# Anaconda Prompt : pip install mysql-connector-python

# Inside File : below

# Pip is a package manager in Python. Installing the MySQL connector ensures your code can connect to a MySQL database.

# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB 330.3 kB/s eta 0:00:44
#    ---------------------------------------- 0.1/14.3 MB 550.5 kB/s eta 0:00:26
#     --------------------------------------- 0.2/14.3 MB 1.4 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/14.3 MB 2.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/14.3 MB 2.5 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/14.3 MB 2.8 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/14.3 MB 2.8 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/14.3 MB 3.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.4/14.3 MB 3.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/14.3 MB 3.4 MB/s eta 0:00:04
# ...

# %%
# These imports are necessary because they allow us to work with data (via pandas) and connect to a database (via mysql.connector).

import pandas as pd
import mysql.connector

# %%
# The mysql.connector.connect() function helps us establish a connection with the database by providing the necessary credentials and details.

# Key Parameters:

# host: Location of the database server. In this case, it’s 'localhost' (the local computer).
# user: Your MySQL username. Here, it is 'root'.
# password: Password associated with the user (e.g., 'Theadora#1995').
# database: The name of the database we want to access (in this example, 'parks_and_recreation').


connect = mysql.connector.connect(
host = 'localhost',
user = 'root',
password = 'Theadora#1995',
database = 'parks_and_recreation'
)

# %%
# SQL (Structured Query Language) is used to interact with databases.
# The query 'SELECT * FROM parks_and_recreation.employee_demographics' retrieves all rows and columns from the employee_demographics table.

query = 'SELECT * FROM parks_and_recreation.employee_demographics'

# %%
# The pandas.read_sql() function reads SQL query results directly into a DataFrame (a table-like structure in pandas).
# Warning: A message appears in the code output, suggesting that using SQLAlchemy for database connections might be more reliable in the future, but the code still works for now.

pd.read_sql(query, connect)
# Out:
# C:\Users\hunte\AppData\Local\Temp\ipykernel_13968\3034383182.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, connect)
#     employee_id first_name     last_name  age  gender  birth_date
# 0             1     Leslie         Knope   44  Female  1979-09-25
# 1             3        Tom     Haverford   36    Male  1987-03-04
# 2             4      April       Ludgate   29  Female  1994-03-27
# 3             5      Jerry       Gergich   61    Male  1962-08-28
# 4             6      Donna        Meagle   46  Female  1977-07-30
# 5             7        Ann       Perkins   35  Female  1988-12-01
# 6             8      Chris       Traeger   43    Male  1980-11-11
# 7             9        Ben         Wyatt   38    Male  1985-07-26
# 8            10       Andy         Dwyer   34    Male  1989-03-25
# ...

# %%
# It is important to close the connection to free up resources and ensure there are no lingering open connections that could cause issues.

connect.close()
