# %% [markdown]
# ### Filtering Using Date Functions

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hunte\Documents\Analyst Workshop\Pandas For Data Analysis\3. Filtering and Ordering\WeatherHistory.csv",
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 15)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 0         3/26/2006  Mostly Cloudy        rain         5.183333
# 1         3/27/2006  Mostly Cloudy        rain         3.722222
# 2         3/28/2006  Mostly Cloudy        rain         4.855556
# 3         3/29/2006          Foggy        rain         5.211111
# 4         3/30/2006       Overcast        rain         6.255556
# ...             ...            ...         ...              ...
# 2358     10/26/2016  Partly Cloudy        snow        -2.155556
# 2359     10/27/2016  Partly Cloudy        snow        -2.816667
# 2360     10/28/2016          Clear        snow        -2.827778
# 2361     10/29/2016  Partly Cloudy        snow        -3.750000
# 2362     10/30/2016  Mostly Cloudy        snow        -4.705556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     4.111111      0.91             5.5384
# 1                     2.566667      0.94             5.2003
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            2363 non-null   object
#  1   Summary                   2363 non-null   object
#  2   Precip Type               2363 non-null   object
#  3   Temperature (C)           2363 non-null   float64
#  4   Apparent Temperature (C)  2363 non-null   float64
#  5   Humidity                  2363 non-null   float64
#  6   Wind Speed (km/h)         2363 non-null   float64
#  7   Wind Bearing (degrees)    2363 non-null   int64
#  8   Visibility (km)           2363 non-null   float64
#  9   Loud Cover                2363 non-null   int64
#  10  Pressure (millibars)      2363 non-null   float64
#  11  Daily Summary             2363 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 221.7+ KB

# %%
pd.to_datetime(df['Formatted Date'])
# Out:
# 0      2006-03-26
# 1      2006-03-27
# 2      2006-03-28
# 3      2006-03-29
# 4      2006-03-30
#           ...
# 2358   2016-10-26
# 2359   2016-10-27
# 2360   2016-10-28
# 2361   2016-10-29
# 2362   2016-10-30
# Name: Formatted Date, Length: 2363, dtype: datetime64[ns]

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            2363 non-null   datetime64[ns]
#  1   Summary                   2363 non-null   object
#  2   Precip Type               2363 non-null   object
#  3   Temperature (C)           2363 non-null   float64
#  4   Apparent Temperature (C)  2363 non-null   float64
#  5   Humidity                  2363 non-null   float64
#  6   Wind Speed (km/h)         2363 non-null   float64
#  7   Wind Bearing (degrees)    2363 non-null   int64
#  8   Visibility (km)           2363 non-null   float64
#  9   Loud Cover                2363 non-null   int64
#  10  Pressure (millibars)      2363 non-null   float64
#  11  Daily Summary             2363 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 221.7+ KB

# %%
df
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 0        2006-03-26  Mostly Cloudy        rain         5.183333
# 1        2006-03-27  Mostly Cloudy        rain         3.722222
# 2        2006-03-28  Mostly Cloudy        rain         4.855556
# 3        2006-03-29          Foggy        rain         5.211111
# 4        2006-03-30       Overcast        rain         6.255556
# ...             ...            ...         ...              ...
# 2358     2016-10-26  Partly Cloudy        snow        -2.155556
# 2359     2016-10-27  Partly Cloudy        snow        -2.816667
# 2360     2016-10-28          Clear        snow        -2.827778
# 2361     2016-10-29  Partly Cloudy        snow        -3.750000
# 2362     2016-10-30  Mostly Cloudy        snow        -4.705556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     4.111111      0.91             5.5384
# 1                     2.566667      0.94             5.2003
# ...

# %%
df[df['Formatted Date'].dt.year == 2006]
# Out:
#     Formatted Date        Summary Precip Type  Temperature (C)  \
# 0       2006-03-26  Mostly Cloudy        rain         5.183333
# 1       2006-03-27  Mostly Cloudy        rain         3.722222
# 2       2006-03-28  Mostly Cloudy        rain         4.855556
# 3       2006-03-29          Foggy        rain         5.211111
# 4       2006-03-30       Overcast        rain         6.255556
# ..             ...            ...         ...              ...
# 213     2006-10-25  Mostly Cloudy        rain        13.033333
# 214     2006-10-26  Mostly Cloudy        rain        17.244444
# 215     2006-10-27  Mostly Cloudy        rain        17.738889
# 216     2006-10-28       Overcast        rain        17.844444
# 217     2006-10-29  Mostly Cloudy        rain        18.861111
#
#      Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                    4.111111      0.91             5.5384
# 1                    2.566667      0.94             5.2003
# ...

# %%
df[df['Formatted Date'].dt.month == 3]
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 0        2006-03-26  Mostly Cloudy        rain         5.183333
# 1        2006-03-27  Mostly Cloudy        rain         3.722222
# 2        2006-03-28  Mostly Cloudy        rain         4.855556
# 3        2006-03-29          Foggy        rain         5.211111
# 4        2006-03-30       Overcast        rain         6.255556
# ...             ...            ...         ...              ...
# 2145     2016-03-27          Foggy        rain         0.022222
# 2146     2016-03-28  Mostly Cloudy        rain         0.238889
# 2147     2016-03-29  Partly Cloudy        rain         0.116667
# 2148     2016-03-30          Clear        rain         1.138889
# 2149     2016-03-31          Clear        rain         0.988889
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                     4.111111      0.91             5.5384
# 1                     2.566667      0.94             5.2003
# ...

# %%
df[df['Formatted Date'].dt.day == 26]
# Out:
#      Formatted Date                   Summary Precip Type  Temperature (C)  \
# 0        2006-03-26             Mostly Cloudy        rain         5.183333
# 31       2006-04-26             Mostly Cloudy        rain        14.255556
# 61       2006-05-26             Mostly Cloudy        rain         7.138889
# 92       2006-06-26                  Overcast        rain         9.050000
# 122      2006-07-26  Breezy and Mostly Cloudy        rain         6.144444
# ...             ...                       ...         ...              ...
# 2236     2016-06-26                     Foggy        snow        -1.500000
# 2266     2016-07-26                     Clear        snow        -2.311111
# 2297     2016-08-26             Partly Cloudy        rain        10.950000
# 2328     2016-09-26             Mostly Cloudy        snow        -2.244444
# 2358     2016-10-26             Partly Cloudy        snow        -2.155556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
df[df['Formatted Date'].dt.day_name() == 'Monday']
# Out:
#      Formatted Date        Summary Precip Type  Temperature (C)  \
# 1        2006-03-27  Mostly Cloudy        rain         3.722222
# 8        2006-04-03  Partly Cloudy        rain        10.116667
# 15       2006-04-10  Partly Cloudy        rain         9.355556
# 22       2006-04-17  Partly Cloudy        rain        10.822222
# 29       2006-04-24  Partly Cloudy        rain        15.388889
# ...             ...            ...         ...              ...
# 2328     2016-09-26  Mostly Cloudy        snow        -2.244444
# 2335     2016-10-03  Partly Cloudy        snow        -4.283333
# 2342     2016-10-10  Mostly Cloudy        snow        -3.655556
# 2349     2016-10-17  Mostly Cloudy        snow        -2.783333
# 2356     2016-10-24  Partly Cloudy        rain         0.255556
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1                     2.566667      0.94             5.2003
# 8                    10.116667      0.79             6.6493
# ...
