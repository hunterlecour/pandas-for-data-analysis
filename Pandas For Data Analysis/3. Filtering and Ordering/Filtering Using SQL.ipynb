# %% [markdown]
# ### Filtering Using SQL

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hunte\Documents\Analyst Workshop\Pandas For Data Analysis\3. Filtering and Ordering\laptop_prices.csv",
                encoding = 'ISO-8859-1')

pd.set_option('display.max.rows', 15)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
# Querying the Data using df.query() Method:
# The query() method allows filtering the DataFrame based on conditions, similar to SQL's WHERE clause.
# Purpose: Displays rows where the Price_usd is greater than 1200.
# How it works: The query method evaluates the expression and returns only matching rows.

# its pulling all the columns where price_usd > 1200

df.query("Price_usd > 1200")
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 0             1   Apple        MacBook Pro           Ultrabook    13.3
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# 7             8   Apple        Macbook Air           Ultrabook    13.3
# ...         ...     ...                ...                 ...     ...
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1259       1277     MSI        GE62 Apache              Gaming    15.6
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
# or operator returns rows where Company is either 'Apple' or 'Dell'

df.query("Company == 'Apple' or Company == 'Dell'")
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 4             5   Apple    MacBook Pro  Ultrabook    13.3
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# ...         ...     ...            ...        ...     ...
# 1278       1296    Dell  Inspiron 3552   Notebook    15.6
# 1281       1299    Dell  Inspiron 3567   Notebook    15.6
# 1290       1308    Dell  Inspiron 3567   Notebook    15.6
# 1292       1310    Dell  Inspiron 3552   Notebook    15.6
# 1295       1313    Dell  Inspiron 3567   Notebook    15.6
#
#                         ScreenResolution  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 3     IPS Panel Retina Display 2880x1800
# 4     IPS Panel Retina Display 2560x1600
# 6     IPS Panel Retina Display 2880x1800
# ...

# %%
# Explanation: This condition selects laptops that are either:
# Made by Apple, or
# Have a price greater than 1500 USD.

df.query("Company == 'Apple' or Price_usd > 1500")
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 0             1   Apple        MacBook Pro           Ultrabook    13.3
# 1             2   Apple        Macbook Air           Ultrabook    13.3
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# ...         ...     ...                ...                 ...     ...
# 1249       1267    Dell             XPS 13  2 in 1 Convertible    13.3
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
# and operator ensures that both conditions are satisfied.

df.query("Company == 'Apple' and Price_usd > 1500")
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 4            5   Apple  MacBook Pro  Ultrabook    13.3
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 15          16   Apple  MacBook Pro  Ultrabook    13.3
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 45          46   Apple  MacBook Pro  Ultrabook    13.3
# 81          83   Apple  MacBook 12"  Ultrabook    12.0
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
# 270        275   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# ...

# %%
# Installing and Using the pandasql Library:

# What is pandasql?
# A library that allows you to run SQL queries on a DataFrame.
# Why use it?
# SQL is often easier for those familiar with database operations.

# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26801 sha256=3b67f39b3c3bee8a957477e15b3ffa0984ca96d631d37a68effda6a59fad3436
#   Stored in directory: c:\users\hunte\appdata\local\pip\cache\wheels\15\a1\e7\6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# ...

# %%
import pandasql as psql

# %%
# SQL Queries on DataFrame Using pandasql:

# sqldf() allows SQL queries on the DataFrame.
# Explanation: This SQL query selects all rows where the Company is 'Apple'.
# Benefit: For users familiar with SQL, this provides an intuitive way to manipulate DataFrames.

psql.sqldf("SELECT * FROM df WHERE Company = 'Apple'")
# Out:
#     laptop_ID Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           4   Apple  MacBook Pro  Ultrabook    15.4
# 3           5   Apple  MacBook Pro  Ultrabook    13.3
# 4           7   Apple  MacBook Pro  Ultrabook    15.4
# ..        ...     ...          ...        ...     ...
# 16        803   Apple  MacBook 12"  Ultrabook    12.0
# 17       1084   Apple  MacBook 12"  Ultrabook    12.0
# 18       1211   Apple  MacBook 12"  Ultrabook    12.0
# 19       1228   Apple  MacBook 12"  Ultrabook    12.0
# 20       1252   Apple  MacBook Air  Ultrabook    11.6
#
#                       ScreenResolution                   Cpu   Ram  \
# 0   IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz   8GB
# 1                             1440x900  Intel Core i5 1.8GHz   8GB
# 2   IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# ...

# %%
psql.sqldf("SELECT * FROM df WHERE Company = 'Apple' And Inches > 14")
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          4   Apple  MacBook Pro  Ultrabook    15.4
# 1          7   Apple  MacBook Pro  Ultrabook    15.4
# 2         13   Apple  MacBook Pro  Ultrabook    15.4
# 3         18   Apple  MacBook Pro  Ultrabook    15.4
#
#                      ScreenResolution                   Cpu   Ram  \
# 0  IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 1  IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 2  IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 3  IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
#
#                 Memory                      Gpu     OpSys  Weight  Price_usd
# 0            512GB SSD       AMD Radeon Pro 455     macOS  1.83kg   2791.195
# 1  256GB Flash Storage  Intel Iris Pro Graphics  Mac OS X  2.04kg   2353.967
# 2            256GB SSD       AMD Radeon Pro 555     macOS  1.83kg   2683.967
# ...

# %%
psql.sqldf("SELECT Company, Inches FROM df WHERE Company = 'Apple' And Inches > 14")
# Out:
#   Company  Inches
# 0   Apple    15.4
# 1   Apple    15.4
# 2   Apple    15.4
# 3   Apple    15.4

# %%
psql.sqldf("SELECT Company FROM df WHERE Company = 'Apple' And Inches > 14")
# Out:
#   Company
# 0   Apple
# 1   Apple
# 2   Apple
# 3   Apple

# %%
type(psql.sqldf("SELECT Company FROM df WHERE Company = 'Apple' And Inches > 14"))
# Out:
# pandas.core.frame.DataFrame

# %%
psql.sqldf("SELECT Company, Product FROM df WHERE Product Like '%MacBook%'")
# Out:
#    Company      Product
# 0    Apple  MacBook Pro
# 1    Apple  Macbook Air
# 2    Apple  MacBook Pro
# 3    Apple  MacBook Pro
# 4    Apple  MacBook Pro
# ..     ...          ...
# 16   Apple  MacBook 12"
# 17   Apple  MacBook 12"
# 18   Apple  MacBook 12"
# 19   Apple  MacBook 12"
# 20   Apple  MacBook Air
#
# [21 rows x 2 columns]

# %%
psql.sqldf("SELECT * FROM df ORDER BY Price_usd")
# Out:
#       laptop_ID Company                               Product     TypeName  \
# 0          1233    Acer      C740-C9QX (3205U/2GB/32GB/Chrome      Netbook
# 1            21    Asus                       Vivobook E200HA      Netbook
# 2          1135    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)     Notebook
# 3            32    Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook
# 4           295    Acer                  Chromebook C910-C2ST     Notebook
# ...         ...     ...                                   ...          ...
# 1298       1081    Asus                            ROG G701VO       Gaming
# 1299        758      HP                              Zbook 17  Workstation
# 1300        617  Lenovo                          Thinkpad P51     Notebook
# 1301        839   Razer                             Blade Pro       Gaming
# 1302        200   Razer                             Blade Pro       Gaming
#
#       Inches                     ScreenResolution  \
# ...

# %%
psql.sqldf("SELECT * FROM df ORDER BY Price_usd DESC")
# Out:
#       laptop_ID Company                               Product     TypeName  \
# 0           200   Razer                             Blade Pro       Gaming
# 1           839   Razer                             Blade Pro       Gaming
# 2           617  Lenovo                          Thinkpad P51     Notebook
# 3           758      HP                              Zbook 17  Workstation
# 4          1081    Asus                            ROG G701VO       Gaming
# ...         ...     ...                                   ...          ...
# 1298         32    Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook
# 1299        295    Acer                  Chromebook C910-C2ST     Notebook
# 1300       1135    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)     Notebook
# 1301         21    Asus                       Vivobook E200HA      Netbook
# 1302       1233    Acer      C740-C9QX (3205U/2GB/32GB/Chrome      Netbook
#
#       Inches                     ScreenResolution  \
# ...
